# %%
from curve import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [5, 5]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['font.family'] = "STZhongsong"
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 定值电阻伏安特性曲线

# %%
d_iU = il("15.6+30.2+45.0+60.0+76.0")
d_iI = il("19.1+37.6+56.1+75.0+94.8")
d_oU = il("15.0+30.1+45.4+60.8+75.2")
d_oI = il("19.8+39.2+59.4+79.4+98.2")
iU = rd(2.5, 100, 0.5, d_iU)
iI = rd(30, 150, 0.5, d_iI)
oU = rd(2.5, 100, 0.5, d_oU)
oI = rd(30, 150, 0.5, d_oI)

# %%
show_data([iU, iI, oU, oI], ['U_inner', 'I_inner', 'U_outer', 'I_outer'])
# Out:
# U_inner: 0.39 0.76 1.12 1.5 1.9
# I_inner: 3.8 7.5 11.2 15.0 19.0
# U_outer: 0.38 0.75 1.13 1.52 1.88
# I_outer: 4.0 7.8 11.9 15.9 19.6

# %%
exp1(iU, iI, oU, oI)

# %% [markdown]
# # 半导体二极管伏安特性曲线

# %%
d_Ua = il("9.8+21.2+33.4+46.2+59.0+70.8+76.4+80.0+81.6+83.2")
d_Ia = il("0.6+1.0+1.8+2.4+3.0+6.0+15.2+41.4+74.2+137.2")
d_Ub = il("34.2+52.4+69.2+76.8+83.8+89.0+92.6+94.8+96.2+97.1")
d_Ib = il("0+0.2+2.1+4.8+10.2+21.6+38.0+57.0+86.9+124.0")
Ua = rd(1, 100, 0.5, d_Ua)
Ia = rd(30, 150, 0.5, d_Ia)
Ub = rd(5, 100, 0.5, d_Ub)
Ib = rd(15, 150, 0.5, d_Ib)

# %%
# d_Ua = il("24.1+34.7+55.6+70.6+75.3+77.4+79.5+81.0+82.4+83.0+73.4+74.0")
# d_Ia = il("0.6+1.5+3.1+6.0+16.5+29.5+59.6+87.2+11.9+140.5+10.2+11.5")
# d_Ub = il("36.6+40.0+41.4+42.6+45.0+46.3+47.3+47.5+47.7+48.0+48.3+48.7")
# d_Ib = il("0.3+1.0+2.1+3.0+7.5+15.1+30.8+48.9+73.9+88.1+106.0+128.5")
# Ua = rd(1, 100, 0.5, d_Ua)
# Ia = rd(30, 150, 0.5, d_Ia)
# Ub = rd(10, 100, 0.5, d_Ub)
# Ib = rd(15, 150, 0.5, d_Ib)

# %%
show_data([Ua, Ia, Ub, Ib], ['U_pos', 'I_pos', 'U_neg', 'I_neg'])
# Out:
# U_pos: 0.098 0.212 0.334 0.462 0.59 0.708 0.764 0.8 0.816 0.832
# I_pos: 0.1 0.2 0.4 0.5 0.6 1.2 3.0 8.3 14.8 27.4
# U_neg: 1.71 2.62 3.46 3.84 4.19 4.45 4.63 4.74 4.81 4.85
# I_neg: 0.0 0.02 0.21 0.48 1.02 2.16 3.8 5.7 8.69 12.4

# %%
exp2(Ua, Ia, Ub, Ib)

# %% [markdown]
# # 晶体三极管的输出特征曲线

# %%
d_U40 = il("0.2+1.0+1.6+2.4+4.0+8.0+12.2+29.2+50.4+64.8")
d_I40 = il("2.0+36.9+53.2+73.4+83.9+85.2+86.0+87.4+89.0+90.0")
d_U60 = il("0.2+1.2+2.0+2.5+4.2+9.8+24.0+44.8+67.4+84.9")
d_I60 = il("24.0+56.1+85.2+102.2+126.2+127.2+127.8+135.0+138.6+142.4")
d_U80 = il("0.1+0.9+1.3+2.5+4.8+8.0+15.2+44.1+67.6+83.6")
d_I80 = il("11.8+15.0+41.1+69.0+85.1+85.8+86.9+90.1+94.1+97.0")
U40 = rd(5, 100, 0.5, d_U40)
I40 = rd(15, 150, 0.5, d_I40)
U60 = rd(5, 100, 0.5, d_U60)
I60 = rd(15, 150, 0.5, d_I60)
U80 = rd(5, 100, 0.5, d_U80)
I80 = rd(30, 150, 0.5, d_I80)

# %%
show_data([U40, I40, U60, I60, U80, I80], ['U40', 'I40', 'U60', 'I60', 'U80', 'I80'])
# Out:
# U40: 0.01 0.05 0.08 0.12 0.2 0.4 0.61 1.46 2.52 3.24
# I40: 0.2 3.69 5.32 7.34 8.39 8.52 8.6 8.74 8.9 9.0
# U60: 0.01 0.06 0.1 0.12 0.21 0.49 1.2 2.24 3.37 4.24
# I60: 2.4 5.61 8.52 10.22 12.62 12.72 12.78 13.5 13.86 14.24
# U80: 0.0 0.05 0.06 0.12 0.24 0.4 0.76 2.2 3.38 4.18
# I80: 2.4 3.0 8.2 13.8 17.0 17.2 17.4 18.0 18.8 19.4

# %%
exp3(U40, I40, U60, I60, U80, I80)
