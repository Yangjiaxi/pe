# %%
from curve import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [5, 5]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['font.family'] = "STZhongsong"
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 定值电阻伏安特性曲线

# %%
iU = il("0.25+0.50+0.75+1.00+1.25+1.50+1.75")
iI = il("2.4+5.0+7.4+10.0+12.5+15.0+17.5")
oU = il("0.25+0.50+0.75+1.00+1.25+1.50+1.75")
oI = il("2.7+5.3+8.0+10.7+13.4+16.0+18.5")

# %%
exp1(iU, iI, oU, oI)

# %% [markdown]
# # 半导体二极管伏安特性曲线

# %%
Ua = il("0.000+0.252+0.330+0.488+0.640+0.740+0.780+0.815+0.830+0.842")
Ia = il("0.0+0.2+0.3+0.5+0.6+1.5+3.7+10.5+20.0+29.4")
Ub = il("0.00+0.60+1.25+1.96+2.76+3.65+4.30+4.65+4.84+4.95")
Ib = il("0.00+0.11+0.25+0.38+0.50+0.82+1.45+2.65+4.95+9.12")

# %%
exp2(Ua, Ia, Ub, Ib)

# %% [markdown]
# # 晶体三极管的输出特征曲线

# %%
U40 = il("0.00+0.05+0.10+0.15+0.20+0.25+1.25+2.15+2.80")
I40 = il("0.00+1.40+3.24+5.92+6.86+7.21+7.39+7.45+7.48")
U60 = il("0.00+0.05+0.10+0.15+0.20+0.25+1.25+2.25+3.25+4.25")
I60 = il("0.00+2.02+5.58+9.00+10.51+10.85+11.12+11.38+11.55+11.71")
U80 = il("0.00+0.05+0.10+0.15+0.20+0.50+1.50+2.75+3.75+4.75")
I80 = il("0.0+3.0+7.0+11.9+14.1+15.2+15.4+15.6+15.8+16.0")

# %%
exp3(U40, I40, U60, I60, U80, I80)
