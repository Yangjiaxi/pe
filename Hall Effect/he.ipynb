# %%
from he import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [4, 4]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['font.family'] = "STZhongsong"
plt.rcParams['axes.unicode_minus'] = False

# %%
V1_1 = np.array(il("1.38+2.07+2.77+3.45+4.15+4.83+5.53+6.22"))
V2_1 = -np.array(il("1.35+2.02+2.70+3.37+4.03+4.72+5.39+6.06"))
V3_1 = np.array(il("1.33+2.00+2.67+3.35+4.03+4.71+5.38+6.05"))
V4_1 = -np.array(il("1.39+2.08+2.78+3.47+4.15+4.85+5.54+6.24"))

# %%
exp1(V1_1, V2_1, V3_1, V4_1)
# Out:
# V_H = [1.3625 2.0425 2.73   3.41   4.09   4.7775 5.46   6.1425]
# k = 1.366
# **************************************************
# R_H = 8.43 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 70.008 (cm^[3]/C)
# R_H = (8.43±0.07)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 7.41 * 10^[14] (cm^[-3])
# U(n) = 6.15 * 10^[12] (cm^[-3])
# n = (7.41±0.06) * 10^[14] (cm^[-3])

# %%
V1_2 = np.array(il("1.46+2.15+2.80+3.48+4.16+4.84+5.52+6.21"))
V2_2 = -np.array(il("1.30+1.98+2.66+3.35+4.02+4.70+5.38+6.06"))
V3_2 = np.array(il("1.28+1.95+2.63+3.31+3.98+4.66+5.35+6.03"))
V4_2 = -np.array(il("1.48+2.17+2.84+3.53+4.21+4.88+5.57+6.24"))

# %%
R_H, U_R_H = exp2(V1_2, V2_2, V3_2, V4_2)
# Out:
# V_H = [1.38   2.0625 2.7325 3.4175 4.0925 4.77   5.455  6.135 ]
# k = 13.58
# **************************************************
# R_H = 8.38 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 69.6 (cm^[3]/C)
# R_H = (8.38±0.07)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 7.46 * 10^[14] (cm^[-3])
# U(n) = 6.19 * 10^[12] (cm^[-3])
# n = (7.46±0.06) * 10^[14] (cm^[-3])

# %%
I_S_3 = np.linspace(0.1, 1, 10)
V_AC = np.array(il("6.2+12.5+18.8+24.6+30.7+36.7+42.6+48.7+54.8+60.7"))

# %%
exp3(I_S_3, V_AC, R_H, U_R_H)
# Out:
# k = 60.37
# **************************************************
# sigma = 2.48 * 10^[-1] (Ω^[-1]/cm)
# Ur(sigma) = 1.16%
# U(sigma) = 2.87 * 10^[-3] (Ω^[-1]/cm)
# sigma = (2.48±0.03) * 10^[-1] (Ω^[-1]/cm)
# **************************************************
# miu = 2.08 * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# Ur(miu) = 1.42%
# U(miu) = 2.96 * 10^[1] (cm^[3]Ω^[-1]C^[-1])
# miu = (2.08±0.03) * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# **************************************************
# n = 7.46 * 10^[14] (cm^[-3])
# U(n) = 6.19 * 10^[12] (cm^[-3])
# n = (7.46±0.06) * 10^[14] (cm^[-3])
