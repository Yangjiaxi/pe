# %%
from he import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [4, 4]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['font.family'] = "STZhongsong"
plt.rcParams['axes.unicode_minus'] = False

# %%
kB = 2.48 * 1000

# %%
V1_1 = np.array(il("1.97+2.94+3.94+4.90+5.89+6.87+7.85+8.83"))
V2_1 = -np.array(il("1.95+2.92+3.89+4.86+5.84+6.80+7.78+8.74"))
V3_1 = np.array(il("1.95+2.91+3.88+4.85+5.83+6.79+7.76+8.73"))
V4_1 = -np.array(il("1.97+2.95+3.95+4.91+5.90+6.88+7.86+8.84"))

# %%
exp1(V1_1, V2_1, V3_1, V4_1, kB)
# Out:
# V_H = [1.96 2.93 3.92 4.88 5.86 6.84 7.81 8.78]
# k = 1.9508
# **************************************************
# R_H = 8.74 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 72.568 (cm^[3]/C)
# R_H = (8.74±0.07)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 7.15 * 10^[14] (cm^[-3])
# U(n) = 5.94 * 10^[12] (cm^[-3])
# n = (7.15±0.06) * 10^[14] (cm^[-3])

# %%
V1_2 = np.array(il("1.55+2.45+3.38+4.32+5.27+6.19+7.14+8.07"))
V2_2 = -np.array(il("2.21+3.16+4.08+5.02+5.97+6.90+7.85+8.77"))
V3_2 = np.array(il("2.21+3.16+4.08+5.02+5.98+6.90+7.85+8.78"))
V4_2 = -np.array(il("1.52+2.47+3.39+4.33+5.28+6.20+7.15+8.08"))

# %%
R_H, U_R_H = exp2(V1_2, V2_2, V3_2, V4_2, kB)
# Out:
# V_H = [1.87 2.81 3.73 4.67 5.62 6.55 7.5  8.42]
# k = 18.74
# **************************************************
# R_H = 8.4 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 69.707 (cm^[3]/C)
# R_H = (8.4±0.07)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 7.44 * 10^[14] (cm^[-3])
# U(n) = 6.18 * 10^[12] (cm^[-3])
# n = (7.44±0.06) * 10^[14] (cm^[-3])

# %%
I_S_3 = np.linspace(0.1, 1, 10)
V_AC = np.array(il("7.1+13.8+20.5+26.7+33.4+40.1+46.8+53.5+59.9+66.9"))

# %%
exp3(I_S_3, V_AC, R_H, U_R_H)
# Out:
# k = 66.24
# **************************************************
# sigma = 2.26 * 10^[-1] (Ω^[-1]/cm)
# Ur(sigma) = 1.16%
# U(sigma) = 2.62 * 10^[-3] (Ω^[-1]/cm)
# sigma = (2.26±0.03) * 10^[-1] (Ω^[-1]/cm)
# **************************************************
# miu = 1.98 * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# Ur(miu) = 1.42%
# U(miu) = 2.82 * 10^[1] (cm^[3]Ω^[-1]C^[-1])
# miu = (1.98±0.03) * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# **************************************************
# n = 7.13 * 10^[14] (cm^[-3])
# U(n) = 5.92 * 10^[12] (cm^[-3])
# n = (7.13±0.06) * 10^[14] (cm^[-3])
