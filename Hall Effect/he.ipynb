# %%
from he import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [4, 4]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['font.family'] = "STZhongsong"
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 先改$k_B$！！！！！！

# %%
kB = 2.72 * 1000

# %% [markdown]
# # ↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑

# %%
V1_1 = np.array(il("2.23+3.35+4.46+5.59+6.70+7.80+8.90+10.03"))
V2_1 = -np.array(il("2.28+3.41+4.54+5.68+6.82+7.94+9.05+10.20"))
V3_1 = np.array(il("2.27+3.40+4.53+5.67+6.81+7.93+9.04+10.19"))
V4_1 = -np.array(il("2.25+3.36+4.47+5.59+6.71+7.81+8.91+10.04"))

# %%
exp1(V1_1, V2_1, V3_1, V4_1, kB)
# Out:
# V_H = [ 2.26  3.38  4.5   5.63  6.76  7.87  8.98 10.11]
# k = 2.2432
# **************************************************
# R_H = 9.16 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 76.083 (cm^[3]/C)
# R_H = (9.16±0.08)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 6.82 * 10^[14] (cm^[-3])
# U(n) = 5.66 * 10^[12] (cm^[-3])
# n = (6.82±0.06) * 10^[14] (cm^[-3])

# %%
V1_2 = np.array(il("2.20+3.26+4.38+5.51+6.64+7.75+8.89+10.01"))
V2_2 = -np.array(il("2.31+3.45+4.57+5.70+6.83+7.94+9.07+10.20"))
V3_2 = np.array(il("2.29+3.43+4.56+5.68+6.82+7.93+9.07+10.19"))
V4_2 = -np.array(il("2.16+3.29+4.41+5.53+6.66+7.78+8.91+10.04"))

# %%
R_H, U_R_H = exp2(V1_2, V2_2, V3_2, V4_2, kB)
# Out:
# V_H = [ 2.24  3.36  4.48  5.6   6.74  7.85  8.98 10.11]
# k = 22.49
# **************************************************
# R_H = 9.19 * 10^[3] (cm^[3]/C)
# Ur(R_H) = 0.83%
# U(R_H) = 76.289 (cm^[3]/C)
# R_H = (9.19±0.08)* 10^[3] (cm^[3]/C)
# **************************************************
# n = 6.8 * 10^[14] (cm^[-3])
# U(n) = 5.65 * 10^[12] (cm^[-3])
# n = (6.8±0.06) * 10^[14] (cm^[-3])

# %%
I_S_3 = np.linspace(0.1, 1, 10)
V_AC = np.array(il("7.7+15.9+23.4+30.8+39.0+46.3+54.4+61.9+69.5+77.6"))

# %%
exp3(I_S_3, V_AC, R_H, U_R_H)
# Out:
# k = 77.27
# **************************************************
# sigma = 1.94 * 10^[-1] (Ω^[-1]/cm)
# Ur(sigma) = 1.16%
# U(sigma) = 2.24 * 10^[-3] (Ω^[-1]/cm)
# sigma = (1.94±0.02) * 10^[-1] (Ω^[-1]/cm)
# **************************************************
# miu = 1.78 * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# Ur(miu) = 1.42%
# U(miu) = 2.54 * 10^[1] (cm^[3]Ω^[-1]C^[-1])
# miu = (1.78±0.03) * 10^[3] (cm^[3]Ω^[-1]C^[-1])
# **************************************************
# n = 6.8 * 10^[14] (cm^[-3])
# U(n) = 5.65 * 10^[12] (cm^[-3])
# n = (6.8±0.06) * 10^[14] (cm^[-3])
