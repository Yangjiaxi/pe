# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
sb.set()
sb.set_style("whitegrid")
plt.rcParams['figure.figsize'] = [6, 6]
plt.rcParams['figure.dpi'] = 144
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['font.family']=['Hei']

# %%
from pe import *

# %%
x = np.linspace(-2, 0, 5).tolist() + np.linspace(1.5, 30.0, 20).tolist()

# %%
y_2mm = il("0+0+0+0.2+0.5+3.0+21.1+28.9+33.3+36.7+39.8+43.7+47.7+51.5+55.0+57.8+60.0+62.2+63.3+65.1+69.7+71.3+73.0+73.7+76.0")
y_4mm = il("0+0+0+0.6+8.2+72.9+112.7+141.0+160.8+179.0+196.1+212+229+237+249+254+262+266+277+282+288+295+297+303+307")
y_8mm = il("0+0+0+5.6+54.5+282+397+478+541+606+665+714+760+801+842+875+902+937+960+985+1008+1031+1046+1067+1088")

# %%
exp2(x, y_2mm, y_4mm, y_8mm)

# %%
gl_size = np.array([2, 4, 8])
gl_436 = [80.2, 305, 1156]
gl_546 = [38.4, 141.6, 543]

# %%
exp3(gl_size, gl_436, gl_546)
